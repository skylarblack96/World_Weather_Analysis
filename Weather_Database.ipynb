# %%
# import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/skylarblack/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/skylarblack/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=62fb261e4d743a7b44d00078fee1a9fd

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append city info into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_desc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taltal
# Processing Record 2 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 1 | yarada
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | altay
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | carbonia
# Processing Record 9 of Set 1 | liuzhou
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | deniliquin
# Processing Record 13 of Set 1 | istok
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | havre-saint-pierre
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | shaki
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | sibut
# Processing Record 23 of Set 1 | penzance
# Processing Record 24 of Set 1 | launceston
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | saint-augustin
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | puerto baquerizo moreno
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | berbera
# Processing Record 34 of Set 1 | sayla
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | college
# Processing Record 39 of Set 1 | necochea
# Processing Record 40 of Set 1 | la ronge
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | pitimbu
# Processing Record 43 of Set 1 | caravelas
# Processing Record 44 of Set 1 | san jose del guaviare
# Processing Record 45 of Set 1 | tuim
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | deogarh
# Processing Record 3 of Set 2 | nisia floresta
# Processing Record 4 of Set 2 | riyadh
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | challapata
# Processing Record 9 of Set 2 | sur
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | robe
# Processing Record 12 of Set 2 | gewane
# Processing Record 13 of Set 2 | provideniya
# Processing Record 14 of Set 2 | suhl
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | jilib
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | pinheiro machado
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | elko
# Processing Record 22 of Set 2 | aracuai
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | andijon
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | kusti
# Processing Record 28 of Set 2 | richards bay
# Processing Record 29 of Set 2 | kayes
# Processing Record 30 of Set 2 | nemuro
# Processing Record 31 of Set 2 | shuangcheng
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | salamiyah
# Processing Record 37 of Set 2 | cockburn town
# Processing Record 38 of Set 2 | nicolas bravo
# Processing Record 39 of Set 2 | chililabombwe
# Processing Record 40 of Set 2 | raditsa-krylovka
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | champerico
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | varhaug
# Processing Record 46 of Set 2 | puerto madryn
# Processing Record 47 of Set 2 | cape town
# Processing Record 48 of Set 2 | albany
# Processing Record 49 of Set 2 | ayan
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | funtua
# Processing Record 2 of Set 3 | batagay-alyta
# Processing Record 3 of Set 3 | bereda
# Processing Record 4 of Set 3 | monrovia
# Processing Record 5 of Set 3 | namatanai
# Processing Record 6 of Set 3 | igarka
# Processing Record 7 of Set 3 | narrabri
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | hasaki
# Processing Record 10 of Set 3 | dhanwar
# Processing Record 11 of Set 3 | vestmanna
# Processing Record 12 of Set 3 | mgandu
# Processing Record 13 of Set 3 | hirosaki
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | bukama
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | neiafu
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | takoradi
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | barabai
# Processing Record 23 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 24 of Set 3 | rostovka
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | kashi
# Processing Record 27 of Set 3 | yumen
# Processing Record 28 of Set 3 | harper
# Processing Record 29 of Set 3 | borovoy
# Processing Record 30 of Set 3 | porbandar
# Processing Record 31 of Set 3 | karratha
# Processing Record 32 of Set 3 | saint-pierre
# Processing Record 33 of Set 3 | ous
# Processing Record 34 of Set 3 | maniitsoq
# Processing Record 35 of Set 3 | izmit
# Processing Record 36 of Set 3 | jalu
# Processing Record 37 of Set 3 | yar-sale
# Processing Record 38 of Set 3 | mezhdurechenskiy
# Processing Record 39 of Set 3 | sao filipe
# Processing Record 40 of Set 3 | roebourne
# Processing Record 41 of Set 3 | ust-ishim
# Processing Record 42 of Set 3 | ypsonas
# Processing Record 43 of Set 3 | grand baie
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 46 of Set 3 | portland
# Processing Record 47 of Set 3 | lompoc
# Processing Record 48 of Set 3 | lahaina
# Processing Record 49 of Set 3 | yatou
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | tucuman
# Processing Record 2 of Set 4 | rafai
# Processing Record 3 of Set 4 | derzhavinsk
# Processing Record 4 of Set 4 | balezino
# Processing Record 5 of Set 4 | viedma
# Processing Record 6 of Set 4 | pervomaysk
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | opuwo
# Processing Record 9 of Set 4 | kupang
# Processing Record 10 of Set 4 | blagoyevo
# Processing Record 11 of Set 4 | tautira
# Processing Record 12 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | carahue
# Processing Record 15 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 4 | vao
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | sesheke
# Processing Record 19 of Set 4 | asau
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | santa cruz
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | lavrentiya
# Processing Record 27 of Set 4 | bulgan
# Processing Record 28 of Set 4 | jumla
# Processing Record 29 of Set 4 | thinadhoo
# Processing Record 30 of Set 4 | fairbanks
# Processing Record 31 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 4 | vaini
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | te anau
# Processing Record 35 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 4 | mokobeng
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | nalut
# Processing Record 39 of Set 4 | norman wells
# Processing Record 40 of Set 4 | sayat
# Processing Record 41 of Set 4 | laguna
# Processing Record 42 of Set 4 | bubaque
# Processing Record 43 of Set 4 | san cristobal
# Processing Record 44 of Set 4 | sisimiut
# Processing Record 45 of Set 4 | boa vista
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | lashio
# Processing Record 48 of Set 4 | kulhudhuffushi
# Processing Record 49 of Set 4 | cherskiy
# Processing Record 50 of Set 4 | merrill
# Processing Record 1 of Set 5 | baykit
# Processing Record 2 of Set 5 | burica
# City not found. Skipping...
# Processing Record 3 of Set 5 | manzhouli
# Processing Record 4 of Set 5 | nuuk
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | kununurra
# Processing Record 7 of Set 5 | buraydah
# Processing Record 8 of Set 5 | koping
# Processing Record 9 of Set 5 | zhangye
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | port hardy
# Processing Record 12 of Set 5 | sijunjung
# Processing Record 13 of Set 5 | kankavli
# City not found. Skipping...
# Processing Record 14 of Set 5 | lasa
# Processing Record 15 of Set 5 | synya
# Processing Record 16 of Set 5 | atar
# Processing Record 17 of Set 5 | yakima
# Processing Record 18 of Set 5 | prince rupert
# Processing Record 19 of Set 5 | padang
# Processing Record 20 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | henties bay
# Processing Record 23 of Set 5 | mandalgovi
# Processing Record 24 of Set 5 | port lincoln
# Processing Record 25 of Set 5 | dolores
# Processing Record 26 of Set 5 | antalaha
# Processing Record 27 of Set 5 | airai
# Processing Record 28 of Set 5 | porto belo
# Processing Record 29 of Set 5 | talnakh
# Processing Record 30 of Set 5 | thunder bay
# Processing Record 31 of Set 5 | flin flon
# Processing Record 32 of Set 5 | pisco
# Processing Record 33 of Set 5 | acari
# Processing Record 34 of Set 5 | castro
# Processing Record 35 of Set 5 | bilma
# Processing Record 36 of Set 5 | araouane
# Processing Record 37 of Set 5 | soyo
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | kinshasa
# Processing Record 40 of Set 5 | ust-maya
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | mafinga
# Processing Record 43 of Set 5 | dikson
# Processing Record 44 of Set 5 | gat
# Processing Record 45 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 5 | ketchikan
# Processing Record 47 of Set 5 | gorontalo
# Processing Record 48 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 5 | acarau
# Processing Record 50 of Set 5 | ocosingo
# Processing Record 1 of Set 6 | karatau
# Processing Record 2 of Set 6 | bonthe
# Processing Record 3 of Set 6 | ngunguru
# Processing Record 4 of Set 6 | puerto ayora
# Processing Record 5 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 6 | chernyshevskiy
# Processing Record 7 of Set 6 | paita
# Processing Record 8 of Set 6 | grindavik
# Processing Record 9 of Set 6 | boende
# Processing Record 10 of Set 6 | luanda
# Processing Record 11 of Set 6 | anito
# Processing Record 12 of Set 6 | kuching
# Processing Record 13 of Set 6 | san patricio
# Processing Record 14 of Set 6 | tanout
# Processing Record 15 of Set 6 | muborak
# Processing Record 16 of Set 6 | yichang
# Processing Record 17 of Set 6 | shakawe
# Processing Record 18 of Set 6 | srednekolymsk
# Processing Record 19 of Set 6 | the pas
# Processing Record 20 of Set 6 | san quintin
# Processing Record 21 of Set 6 | kuroiso
# Processing Record 22 of Set 6 | ahipara
# Processing Record 23 of Set 6 | santa maria
# Processing Record 24 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 6 | akdepe
# Processing Record 26 of Set 6 | rorvik
# Processing Record 27 of Set 6 | tura
# Processing Record 28 of Set 6 | baruun-urt
# Processing Record 29 of Set 6 | narsaq
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | cambre
# Processing Record 33 of Set 6 | placido de castro
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | praya
# Processing Record 36 of Set 6 | labuhan
# Processing Record 37 of Set 6 | pangnirtung
# Processing Record 38 of Set 6 | vila velha
# Processing Record 39 of Set 6 | salalah
# Processing Record 40 of Set 6 | atbasar
# Processing Record 41 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 6 | grand gaube
# Processing Record 43 of Set 6 | luderitz
# Processing Record 44 of Set 6 | sumenep
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | masunga
# Processing Record 47 of Set 6 | pecos
# Processing Record 48 of Set 6 | kuytun
# Processing Record 49 of Set 6 | aksarka
# Processing Record 50 of Set 6 | maxixe
# Processing Record 1 of Set 7 | domoni
# Processing Record 2 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 7 | san
# Processing Record 4 of Set 7 | faanui
# Processing Record 5 of Set 7 | chagoda
# Processing Record 6 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 7 of Set 7 | simpang
# Processing Record 8 of Set 7 | komsomolskiy
# Processing Record 9 of Set 7 | zabol
# Processing Record 10 of Set 7 | nyurba
# Processing Record 11 of Set 7 | hirara
# Processing Record 12 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 7 | bilibino
# Processing Record 15 of Set 7 | ibra
# Processing Record 16 of Set 7 | portsmouth
# Processing Record 17 of Set 7 | ureki
# Processing Record 18 of Set 7 | santo antonio do ica
# Processing Record 19 of Set 7 | nioro
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | sao jose da coroa grande
# Processing Record 22 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 23 of Set 7 | mount isa
# Processing Record 24 of Set 7 | conceicao do araguaia
# Processing Record 25 of Set 7 | kamalpur
# Processing Record 26 of Set 7 | cheney
# Processing Record 27 of Set 7 | ouesso
# Processing Record 28 of Set 7 | det udom
# Processing Record 29 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 7 | saint-joseph
# Processing Record 31 of Set 7 | singkang
# Processing Record 32 of Set 7 | hearst
# Processing Record 33 of Set 7 | funadhoo
# Processing Record 34 of Set 7 | west bay
# Processing Record 35 of Set 7 | hofn
# Processing Record 36 of Set 7 | rio bananal
# Processing Record 37 of Set 7 | egvekinot
# Processing Record 38 of Set 7 | athens
# Processing Record 39 of Set 7 | valparaiso
# Processing Record 40 of Set 7 | tahoua
# Processing Record 41 of Set 7 | auki
# Processing Record 42 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 7 | mulege
# Processing Record 44 of Set 7 | aleksandrov gay
# Processing Record 45 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 7 | chimbote
# Processing Record 48 of Set 7 | takestan
# Processing Record 49 of Set 7 | mandiana
# Processing Record 50 of Set 7 | slamannan
# Processing Record 1 of Set 8 | puerto escondido
# Processing Record 2 of Set 8 | namibe
# Processing Record 3 of Set 8 | burnie
# Processing Record 4 of Set 8 | krasnoselkup
# Processing Record 5 of Set 8 | itatiba
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | klaksvik
# Processing Record 8 of Set 8 | coquimbo
# Processing Record 9 of Set 8 | vila
# Processing Record 10 of Set 8 | le port
# Processing Record 11 of Set 8 | jiwani
# Processing Record 12 of Set 8 | mayo
# Processing Record 13 of Set 8 | san cataldo
# Processing Record 14 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 8 | trincomalee
# Processing Record 16 of Set 8 | koumac
# Processing Record 17 of Set 8 | jardim
# Processing Record 18 of Set 8 | lagoa
# Processing Record 19 of Set 8 | yarensk
# Processing Record 20 of Set 8 | kalmunai
# Processing Record 21 of Set 8 | lushoto
# Processing Record 22 of Set 8 | houma
# Processing Record 23 of Set 8 | vanimo
# Processing Record 24 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 8 | quatre cocos
# Processing Record 26 of Set 8 | kutum
# Processing Record 27 of Set 8 | assare
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 8 | maningrida
# Processing Record 31 of Set 8 | bowen
# Processing Record 32 of Set 8 | arlit
# Processing Record 33 of Set 8 | okha
# Processing Record 34 of Set 8 | guiratinga
# Processing Record 35 of Set 8 | turukhansk
# Processing Record 36 of Set 8 | ulagan
# Processing Record 37 of Set 8 | abiy adi
# City not found. Skipping...
# Processing Record 38 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 8 | lerwick
# Processing Record 40 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 8 | doha
# Processing Record 42 of Set 8 | marrakesh
# Processing Record 43 of Set 8 | cairns
# Processing Record 44 of Set 8 | plouzane
# Processing Record 45 of Set 8 | panevezys
# Processing Record 46 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 8 | brae
# Processing Record 48 of Set 8 | iskateley
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | pangai
# Processing Record 1 of Set 9 | conway
# Processing Record 2 of Set 9 | marawi
# Processing Record 3 of Set 9 | fortuna
# Processing Record 4 of Set 9 | kozulka
# Processing Record 5 of Set 9 | iglesias
# Processing Record 6 of Set 9 | guozhen
# Processing Record 7 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 9 | hobyo
# Processing Record 9 of Set 9 | magan
# Processing Record 10 of Set 9 | morant bay
# Processing Record 11 of Set 9 | muroto
# Processing Record 12 of Set 9 | adre
# Processing Record 13 of Set 9 | pelym
# Processing Record 14 of Set 9 | blanquefort
# Processing Record 15 of Set 9 | neftekamsk
# Processing Record 16 of Set 9 | erenhot
# Processing Record 17 of Set 9 | banjar
# Processing Record 18 of Set 9 | mackay
# Processing Record 19 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 9 | aanekoski
# Processing Record 21 of Set 9 | aracati
# Processing Record 22 of Set 9 | chara
# Processing Record 23 of Set 9 | kostyantynivka
# Processing Record 24 of Set 9 | talaya
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 9 | avera
# Processing Record 29 of Set 9 | leshukonskoye
# Processing Record 30 of Set 9 | kasungu
# Processing Record 31 of Set 9 | panlaitan
# Processing Record 32 of Set 9 | maragogi
# Processing Record 33 of Set 9 | vestmannaeyjar
# Processing Record 34 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 35 of Set 9 | biltine
# Processing Record 36 of Set 9 | avon
# Processing Record 37 of Set 9 | mecca
# Processing Record 38 of Set 9 | inuvik
# Processing Record 39 of Set 9 | soddy-daisy
# Processing Record 40 of Set 9 | sturgeon bay
# Processing Record 41 of Set 9 | nangong
# Processing Record 42 of Set 9 | rocha
# Processing Record 43 of Set 9 | ust-kuyga
# Processing Record 44 of Set 9 | bindura
# Processing Record 45 of Set 9 | bumba
# Processing Record 46 of Set 9 | saint-georges
# Processing Record 47 of Set 9 | lakes entrance
# Processing Record 48 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 9 | mananjary
# Processing Record 50 of Set 9 | sargatskoye
# Processing Record 1 of Set 10 | castleisland
# Processing Record 2 of Set 10 | cap malheureux
# Processing Record 3 of Set 10 | erzin
# Processing Record 4 of Set 10 | digby
# Processing Record 5 of Set 10 | ust-barguzin
# Processing Record 6 of Set 10 | guerrero negro
# Processing Record 7 of Set 10 | dunedin
# Processing Record 8 of Set 10 | gzhatsk
# City not found. Skipping...
# Processing Record 9 of Set 10 | pochutla
# Processing Record 10 of Set 10 | kamenka
# Processing Record 11 of Set 10 | mananara
# Processing Record 12 of Set 10 | half moon bay
# Processing Record 13 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 10 | methoni
# Processing Record 15 of Set 10 | beatrice
# Processing Record 16 of Set 10 | kodinsk
# Processing Record 17 of Set 10 | phek
# Processing Record 18 of Set 10 | iwanai
# Processing Record 19 of Set 10 | storforshei
# Processing Record 20 of Set 10 | severo-kurilsk
# Processing Record 21 of Set 10 | phuket
# Processing Record 22 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 10 | porto novo
# Processing Record 24 of Set 10 | bontang
# Processing Record 25 of Set 10 | catabola
# Processing Record 26 of Set 10 | san francisco
# Processing Record 27 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 28 of Set 10 | taganak
# Processing Record 29 of Set 10 | rongcheng
# Processing Record 30 of Set 10 | a
# City not found. Skipping...
# Processing Record 31 of Set 10 | tutoia
# Processing Record 32 of Set 10 | bandarban
# Processing Record 33 of Set 10 | concepcion del oro
# Processing Record 34 of Set 10 | beyneu
# Processing Record 35 of Set 10 | leiyang
# Processing Record 36 of Set 10 | kushima
# Processing Record 37 of Set 10 | ulaanbaatar
# Processing Record 38 of Set 10 | broken hill
# Processing Record 39 of Set 10 | porto santo
# Processing Record 40 of Set 10 | kontagora
# Processing Record 41 of Set 10 | lata
# Processing Record 42 of Set 10 | senigallia
# Processing Record 43 of Set 10 | utinga
# Processing Record 44 of Set 10 | comodoro rivadavia
# Processing Record 45 of Set 10 | birjand
# Processing Record 46 of Set 10 | palauig
# Processing Record 47 of Set 10 | starosubkhangulovo
# Processing Record 48 of Set 10 | mehamn
# Processing Record 49 of Set 10 | calama
# Processing Record 50 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 11 | laje
# Processing Record 2 of Set 11 | shizunai
# Processing Record 3 of Set 11 | san carlos de bariloche
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | belmonte
# Processing Record 6 of Set 11 | lunenburg
# Processing Record 7 of Set 11 | rudkobing
# Processing Record 8 of Set 11 | san jeronimo
# Processing Record 9 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 10 of Set 11 | bakel
# Processing Record 11 of Set 11 | pingliang
# Processing Record 12 of Set 11 | port keats
# Processing Record 13 of Set 11 | rio rancho
# Processing Record 14 of Set 11 | boden
# Processing Record 15 of Set 11 | tuatapere
# Processing Record 16 of Set 11 | santiago del estero
# Processing Record 17 of Set 11 | katrineholm
# Processing Record 18 of Set 11 | jaipur hat
# City not found. Skipping...
# Processing Record 19 of Set 11 | tambura
# Processing Record 20 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 21 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 22 of Set 11 | marzuq
# Processing Record 23 of Set 11 | ambulu
# Processing Record 24 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 11 | vung tau
# Processing Record 26 of Set 11 | naryan-mar
# Processing Record 27 of Set 11 | birao
# Processing Record 28 of Set 11 | ekhinos
# Processing Record 29 of Set 11 | san policarpo
# Processing Record 30 of Set 11 | pevek
# Processing Record 31 of Set 11 | les cayes
# Processing Record 32 of Set 11 | kinablangan
# Processing Record 33 of Set 11 | akyab
# Processing Record 34 of Set 11 | linjiang
# Processing Record 35 of Set 11 | blyth
# Processing Record 36 of Set 11 | aswan
# Processing Record 37 of Set 11 | alice springs
# Processing Record 38 of Set 11 | firovo
# Processing Record 39 of Set 11 | sanary-sur-mer
# Processing Record 40 of Set 11 | chapais
# Processing Record 41 of Set 11 | that phanom
# Processing Record 42 of Set 11 | kota kinabalu
# Processing Record 43 of Set 11 | solnechnyy
# Processing Record 44 of Set 11 | wilmington
# Processing Record 45 of Set 11 | ngaoundere
# Processing Record 46 of Set 11 | bousso
# Processing Record 47 of Set 11 | dwarka
# Processing Record 48 of Set 11 | isla mujeres
# Processing Record 49 of Set 11 | constitucion
# Processing Record 50 of Set 11 | ambon
# Processing Record 1 of Set 12 | kulykiv
# Processing Record 2 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 12 | iralaya
# Processing Record 5 of Set 12 | bandarbeyla
# Processing Record 6 of Set 12 | warrington
# Processing Record 7 of Set 12 | pontal do parana
# Processing Record 8 of Set 12 | saint anthony
# Processing Record 9 of Set 12 | hami
# Processing Record 10 of Set 12 | hagere hiywet
# Processing Record 11 of Set 12 | numan
# Processing Record 12 of Set 12 | baneh
# Processing Record 13 of Set 12 | terre haute
# Processing Record 14 of Set 12 | makasar
# Processing Record 15 of Set 12 | zapolyarnyy
# Processing Record 16 of Set 12 | miandrivazo
# Processing Record 17 of Set 12 | longyearbyen
# Processing Record 18 of Set 12 | semey
# Processing Record 19 of Set 12 | massaguet
# Processing Record 20 of Set 12 | sananduva
# Processing Record 21 of Set 12 | pokosnoye
# Processing Record 22 of Set 12 | broome
# Processing Record 23 of Set 12 | aksu
# Processing Record 24 of Set 12 | zhigalovo
# Processing Record 25 of Set 12 | vaitape
# Processing Record 26 of Set 12 | asosa
# Processing Record 27 of Set 12 | berlevag
# Processing Record 28 of Set 12 | nuevo progreso
# Processing Record 29 of Set 12 | cumberland
# Processing Record 30 of Set 12 | tibu
# Processing Record 31 of Set 12 | northam
# Processing Record 32 of Set 12 | spearfish
# Processing Record 33 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 12 | naron
# Processing Record 35 of Set 12 | tessalit
# Processing Record 36 of Set 12 | yelizovo
# Processing Record 37 of Set 12 | yakeshi
# Processing Record 38 of Set 12 | walvis bay
# Processing Record 39 of Set 12 | salym
# Processing Record 40 of Set 12 | peniche
# Processing Record 41 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 12 | sola
# Processing Record 43 of Set 12 | nassau
# Processing Record 44 of Set 12 | inta
# Processing Record 45 of Set 12 | hwange
# Processing Record 46 of Set 12 | buala
# Processing Record 47 of Set 12 | changping
# Processing Record 48 of Set 12 | kysyl-syr
# Processing Record 49 of Set 12 | prado
# Processing Record 50 of Set 12 | bahia honda
# Processing Record 1 of Set 13 | porto walter
# Processing Record 2 of Set 13 | puerto ayacucho
# Processing Record 3 of Set 13 | port augusta
# Processing Record 4 of Set 13 | manta
# Processing Record 5 of Set 13 | biu
# Processing Record 6 of Set 13 | chicama
# Processing Record 7 of Set 13 | totness
# Processing Record 8 of Set 13 | wau
# Processing Record 9 of Set 13 | rio gallegos
# Processing Record 10 of Set 13 | gizo
# Processing Record 11 of Set 13 | beidao
# Processing Record 12 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 13 | batemans bay
# Processing Record 14 of Set 13 | kiruna
# Processing Record 15 of Set 13 | atambua
# Processing Record 16 of Set 13 | mao
# Processing Record 17 of Set 13 | adrar
# Processing Record 18 of Set 13 | camacha
# Processing Record 19 of Set 13 | toamasina
# Processing Record 20 of Set 13 | kolimvari
# City not found. Skipping...
# Processing Record 21 of Set 13 | iquique
# Processing Record 22 of Set 13 | san miguelito
# Processing Record 23 of Set 13 | colorines
# Processing Record 24 of Set 13 | ndiekro
# City not found. Skipping...
# Processing Record 25 of Set 13 | victoria point
# Processing Record 26 of Set 13 | alto lucero
# Processing Record 27 of Set 13 | olinda
# Processing Record 28 of Set 13 | ust-nera
# Processing Record 29 of Set 13 | glubokoe
# City not found. Skipping...
# Processing Record 30 of Set 13 | rumphi
# Processing Record 31 of Set 13 | lappeenranta
# Processing Record 32 of Set 13 | vardo
# Processing Record 33 of Set 13 | shache
# Processing Record 34 of Set 13 | lafiagi
# Processing Record 35 of Set 13 | lebanon
# Processing Record 36 of Set 13 | batticaloa
# Processing Record 37 of Set 13 | mosquera
# Processing Record 38 of Set 13 | bouake
# Processing Record 39 of Set 13 | skibotn
# Processing Record 40 of Set 13 | hope
# Processing Record 41 of Set 13 | port hedland
# Processing Record 42 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 13 | carutapera
# Processing Record 44 of Set 13 | bossangoa
# Processing Record 45 of Set 13 | ballina
# Processing Record 46 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 47 of Set 13 | ceres
# Processing Record 48 of Set 13 | aykhal
# Processing Record 49 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 50 of Set 13 | raga
# Processing Record 1 of Set 14 | zabaykalsk
# Processing Record 2 of Set 14 | yerbogachen
# Processing Record 3 of Set 14 | navalgund
# Processing Record 4 of Set 14 | bethel
# Processing Record 5 of Set 14 | maralal
# Processing Record 6 of Set 14 | ambilobe
# Processing Record 7 of Set 14 | la palma
# Processing Record 8 of Set 14 | gubkinskiy
# Processing Record 9 of Set 14 | velizh
# Processing Record 10 of Set 14 | keuruu
# Processing Record 11 of Set 14 | buchanan
# Processing Record 12 of Set 14 | aklavik
# Processing Record 13 of Set 14 | san andres
# Processing Record 14 of Set 14 | sao miguel do guama
# Processing Record 15 of Set 14 | plateros
# Processing Record 16 of Set 14 | yarmouth
# Processing Record 17 of Set 14 | barra patuca
# Processing Record 18 of Set 14 | samsun
# Processing Record 19 of Set 14 | la romana
# Processing Record 20 of Set 14 | floriano
# Processing Record 21 of Set 14 | palasa
# Processing Record 22 of Set 14 | khuzdar
# Processing Record 23 of Set 14 | fuyang
# Processing Record 24 of Set 14 | aripuana
# Processing Record 25 of Set 14 | port blair
# Processing Record 26 of Set 14 | jos
# Processing Record 27 of Set 14 | olafsvik
# Processing Record 28 of Set 14 | amvrosiyivka
# Processing Record 29 of Set 14 | humaita
# Processing Record 30 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 31 of Set 14 | kafue
# Processing Record 32 of Set 14 | lisakovsk
# Processing Record 33 of Set 14 | seminole
# Processing Record 34 of Set 14 | moron
# Processing Record 35 of Set 14 | bodrum
# Processing Record 36 of Set 14 | kanigoro
# Processing Record 37 of Set 14 | edd
# Processing Record 38 of Set 14 | dingle
# Processing Record 39 of Set 14 | kavaratti
# Processing Record 40 of Set 14 | lokosovo
# Processing Record 41 of Set 14 | yeppoon
# Processing Record 42 of Set 14 | pozo colorado
# Processing Record 43 of Set 14 | asyut
# Processing Record 44 of Set 14 | ilam
# Processing Record 45 of Set 14 | selikhino
# Processing Record 46 of Set 14 | kanash
# Processing Record 47 of Set 14 | pa sang
# Processing Record 48 of Set 14 | dallas
# Processing Record 49 of Set 14 | uspenka
# Processing Record 50 of Set 14 | leon
# Processing Record 1 of Set 15 | rokupr
# Processing Record 2 of Set 15 | aktau
# Processing Record 3 of Set 15 | manzanillo
# Processing Record 4 of Set 15 | graciano sanchez
# Processing Record 5 of Set 15 | la baule-escoublac
# Processing Record 6 of Set 15 | curillo
# Processing Record 7 of Set 15 | progreso
# Processing Record 8 of Set 15 | san juan
# Processing Record 9 of Set 15 | oranjestad
# Processing Record 10 of Set 15 | nishihara
# Processing Record 11 of Set 15 | kudahuvadhoo
# Processing Record 12 of Set 15 | baghmara
# Processing Record 13 of Set 15 | asekeyevo
# Processing Record 14 of Set 15 | sovetskiy
# Processing Record 15 of Set 15 | insar
# Processing Record 16 of Set 15 | fort nelson
# Processing Record 17 of Set 15 | khromtau
# Processing Record 18 of Set 15 | kurilsk
# Processing Record 19 of Set 15 | awassa
# Processing Record 20 of Set 15 | robertsport
# Processing Record 21 of Set 15 | georgiyevskoye
# Processing Record 22 of Set 15 | loreto
# Processing Record 23 of Set 15 | nouadhibou
# Processing Record 24 of Set 15 | chapada dos guimaraes
# Processing Record 25 of Set 15 | mayumba
# Processing Record 26 of Set 15 | najran
# Processing Record 27 of Set 15 | sobolevo
# Processing Record 28 of Set 15 | sao joao da barra
# Processing Record 29 of Set 15 | rosarito
# Processing Record 30 of Set 15 | ewa beach
# Processing Record 31 of Set 15 | sangar
# Processing Record 32 of Set 15 | hojai
# Processing Record 33 of Set 15 | verkhoyansk
# Processing Record 34 of Set 15 | anchorage
# Processing Record 35 of Set 15 | olga
# Processing Record 36 of Set 15 | bitung
# Processing Record 37 of Set 15 | emerald
# Processing Record 38 of Set 15 | nampula
# Processing Record 39 of Set 15 | price
# Processing Record 40 of Set 15 | oxbow
# Processing Record 41 of Set 15 | nanchang
# Processing Record 42 of Set 15 | mae sai
# Processing Record 43 of Set 15 | jurado
# Processing Record 44 of Set 15 | baherove
# Processing Record 45 of Set 15 | lake city
# Processing Record 46 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 47 of Set 15 | prieska
# Processing Record 48 of Set 15 | isangel
# Processing Record 49 of Set 15 | kedrovyy
# Processing Record 50 of Set 15 | coronado
# Processing Record 1 of Set 16 | codrington
# Processing Record 2 of Set 16 | sorland
# Processing Record 3 of Set 16 | ormara
# Processing Record 4 of Set 16 | yaan
# Processing Record 5 of Set 16 | salinopolis
# Processing Record 6 of Set 16 | sabang
# Processing Record 7 of Set 16 | gornopravdinsk
# Processing Record 8 of Set 16 | taquari
# Processing Record 9 of Set 16 | manono
# Processing Record 10 of Set 16 | sambava
# Processing Record 11 of Set 16 | gladstone
# Processing Record 12 of Set 16 | kemin
# Processing Record 13 of Set 16 | goderich
# Processing Record 14 of Set 16 | kamina
# Processing Record 15 of Set 16 | plettenberg bay
# Processing Record 16 of Set 16 | tygda
# Processing Record 17 of Set 16 | santa fe
# Processing Record 18 of Set 16 | zyryanovsk
# Processing Record 19 of Set 16 | skibbereen
# Processing Record 20 of Set 16 | pokhara
# Processing Record 21 of Set 16 | panama city
# Processing Record 22 of Set 16 | waddan
# Processing Record 23 of Set 16 | karpathos
# Processing Record 24 of Set 16 | hueytown
# Processing Record 25 of Set 16 | abu samrah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of dictionaries to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Taltal -25.4000  -70.4833     64.53        80           8
# 1          Yarada  17.6500   83.2667     82.36        69          31
# 2        Hermanus -34.4187   19.2345     64.99        91         100
# 3           Altay  47.8667   88.1167     47.75        47          74
# 4      Chokurdakh  70.6333  147.9167     10.83        90          66
# 5  Ribeira Grande  38.5167  -28.7000     61.59        83          82
# 6        Carbonia  39.1672    8.5222     44.01        87          20
# 7         Liuzhou  24.3126  109.3892     64.36        93         100
# 8         Mataura -46.1927  168.8643     64.00        69          67
# 9           Kapaa  22.0752 -159.3190     80.60        57          40
#
#    Wind Speed Country       Description
# 0        6.08      CL         clear sky
# 1       10.00      IN  scattered clouds
# 2       11.10      ZA        light rain
# 3        4.50      CN     broken clouds
# 4       13.04      RU     broken clouds
# 5        7.34      PT     broken clouds
# 6        2.30      IT        few clouds
# 7        4.36      CN   overcast clouds
# 8        5.01      NZ     broken clouds
# 9       13.80      US  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
